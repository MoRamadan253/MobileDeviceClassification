# %%
import pandas as pd

# %%
test = pd.read_csv("/content/test - test.csv")

# %%
test['volume'] = test['sc_w'] * test['sc_h'] * test['m_dep']
test = test.drop(['sc_w', 'sc_h', 'm_dep','id'], axis=1)

# %%
from joblib import load

# Load the saved model from file
loaded_model = load('/content/svm_classifier_best.joblib')

# Use the loaded model for predictions
predictions = loaded_model.predict(test)

# %%
test['predictions'] = predictions

# %%
test
# Out:
#      battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0             1043     1          1.8         1  14       0           5
# 1              841     1          0.5         1   4       1          61
# 2             1807     1          2.8         0   1       0          27
# 3             1546     0          0.5         1  18       1          25
# 4             1434     0          1.4         0  11       1          49
# ..             ...   ...          ...       ...  ..     ...         ...
# 995           1700     1          1.9         0   0       1          54
# 996            609     0          1.8         1   0       0          13
# 997           1185     0          1.4         0   1       1           8
# 998           1533     1          0.5         1   0       0          50
# 999           1270     1          0.5         0   4       1          35
#
#      mobile_wt  n_cores  pc  px_height  px_width   ram  talk_time  three_g  \
# ...
